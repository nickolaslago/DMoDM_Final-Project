# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy  as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import sys
np.set_printoptions(threshold=sys.maxsize)
np.set_printoptions(suppress=True)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# # Import Data

# %%
df = pd.read_sas('../a2z_insurance.sas7bdat')

df.shape
df.info()
df.head(10)
# Out:
# (10296, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         10296 non-null  float64
#  1   FirstPolYear   10266 non-null  float64
#  2   BirthYear      10279 non-null  float64
#  3   EducDeg        10279 non-null  object
#  4   MonthSal       10260 non-null  float64
#  5   GeoLivArea     10295 non-null  float64
#  6   Children       10275 non-null  float64
#  7   CustMonVal     10296 non-null  float64
#  8   ClaimsRate     10296 non-null  float64
#  9   PremMotor      10262 non-null  float64
#  10  PremHousehold  10296 non-null  float64
#  11  PremHealth     10253 non-null  float64
#  12  PremLife       10192 non-null  float64
#  13  PremWork       10210 non-null  float64
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB
#     CustID  FirstPolYear  BirthYear             EducDeg   MonthSal  \
# 0  1.00000    1985.00000 1982.00000  b'2 - High School' 2177.00000
# 1  2.00000    1981.00000 1995.00000  b'2 - High School'  677.00000
# 2  3.00000    1991.00000 1970.00000        b'1 - Basic' 2277.00000
# 3  4.00000    1990.00000 1981.00000      b'3 - BSc/MSc' 1099.00000
# 4  5.00000    1986.00000 1973.00000      b'3 - BSc/MSc' 1763.00000
# 5  6.00000    1986.00000 1956.00000  b'2 - High School' 2566.00000
# 6  7.00000    1979.00000 1943.00000  b'2 - High School' 4103.00000
# 7  8.00000    1988.00000 1974.00000  b'2 - High School' 1743.00000
# 8  9.00000    1981.00000 1978.00000      b'3 - BSc/MSc' 1862.00000
# 9 10.00000    1976.00000 1948.00000      b'3 - BSc/MSc' 3842.00000
#
#    GeoLivArea  Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# 0     1.00000   1.00000   380.97000     0.39000  375.85000       79.45000
# 1     4.00000   1.00000  -131.13000     1.12000   77.46000      416.20000
# 2     3.00000   0.00000   504.67000     0.28000  206.15000      224.50000
# 3     4.00000   1.00000   -16.99000     0.99000  182.48000       43.35000
# 4     4.00000   1.00000    35.23000     0.90000  338.62000       47.80000
# 5     4.00000   1.00000   -24.33000     1.00000  440.75000       18.90000
# 6     4.00000   0.00000   -66.01000     1.05000  156.92000      295.60000
# 7     4.00000   1.00000  -144.91000     1.13000  248.27000      397.30000
# 8     1.00000   1.00000   356.53000     0.36000  344.51000       18.35000
# 9     1.00000   0.00000  -119.35000     1.12000  209.26000      182.25000
#
#    PremHealth  PremLife  PremWork
# 0   146.36000  47.01000  16.89000
# 1   116.69000 194.48000 106.13000
# 2   124.58000  86.35000  99.02000
# 3   311.17000  35.34000  28.34000
# 4   182.59000  18.78000  41.45000
# 5   114.80000   7.00000   7.67000
# 6   317.95000  14.67000  26.34000
# 7   144.36000  66.68000  53.23000
# 8   210.04000   8.78000   9.89000
# 9   271.94000  39.23000  55.12000

# %%
df.describe(include='all').T
# Out:
#                     count unique             top  freq       mean        std  \
# CustID        10296.00000    NaN             NaN   NaN 5148.50000 2972.34352
# FirstPolYear  10266.00000    NaN             NaN   NaN 1991.06263  511.26791
# BirthYear     10279.00000    NaN             NaN   NaN 1968.00778   19.70948
# EducDeg             10279      4  b'3 - BSc/MSc'  4799        NaN        NaN
# MonthSal      10260.00000    NaN             NaN   NaN 2506.66706 1157.44963
# GeoLivArea    10295.00000    NaN             NaN   NaN    2.70986    1.26629
# Children      10275.00000    NaN             NaN   NaN    0.70676    0.45527
# CustMonVal    10296.00000    NaN             NaN   NaN  177.89260 1945.81151
# ClaimsRate    10296.00000    NaN             NaN   NaN    0.74277    2.91696
# PremMotor     10262.00000    NaN             NaN   NaN  300.47025  211.91500
# PremHousehold 10296.00000    NaN             NaN   NaN  210.43119  352.59598
# PremHealth    10253.00000    NaN             NaN   NaN  171.58083  296.40598
# PremLife      10192.00000    NaN             NaN   NaN   41.85578   47.48063
# PremWork      10210.00000    NaN             NaN   NaN   41.27751   51.51357
#
#                         min        25%        50%        75%         max
# CustID              1.00000 2574.75000 5148.50000 7722.25000 10296.00000
# FirstPolYear     1974.00000 1980.00000 1986.00000 1992.00000 53784.00000
# BirthYear        1028.00000 1953.00000 1968.00000 1983.00000  2001.00000
# EducDeg                 NaN        NaN        NaN        NaN         NaN
# MonthSal          333.00000 1706.00000 2501.50000 3290.25000 55215.00000
# GeoLivArea          1.00000    1.00000    3.00000    4.00000     4.00000
# Children            0.00000    0.00000    1.00000    1.00000     1.00000
# CustMonVal    -165680.42000   -9.44000  186.87000  399.77750 11875.89000
# ClaimsRate          0.00000    0.39000    0.72000    0.98000   256.20000
# PremMotor          -4.11000  190.59000  298.61000  408.30000 11604.42000
# PremHousehold     -75.00000   49.45000  132.80000  290.05000 25048.80000
# PremHealth         -2.11000  111.80000  162.81000  219.82000 28272.00000
# PremLife           -7.00000    9.89000   25.56000   57.79000   398.30000
# PremWork          -12.00000   10.67000   25.67000   56.79000  1988.70000

# %% [markdown]
# ## Criação Variáveis

# %%
df['Age'] = 2016 - df.BirthYear
df['YearsOfCustomer'] = 2016 - df.FirstPolYear
df['PremSum'] = df['PremMotor'] + df['PremHousehold'] + df['PremHealth'] + df['PremLife'] + df['PremWork']

df['MonthlyPremMotor'] = df['PremMotor']/12
df['MonthlyPremHousehold'] = df['PremHousehold']/12
df['MonthlyPremHealth'] = df['PremHealth']/12
df['MonthlyPremLife'] = df['PremLife']/12
df['MonthlyPremWork'] = df['PremWork']/12
df['MonthlyPremSum'] = df['PremSum']/12
df['YearlyMonthSal'] = df['MonthSal']*12
df.rename(columns={"PremMotor": "YearlyPremMotor", 
                   "PremHousehold": "YearlyPremHousehold",
                   "PremHealth" : "YearlyPremHealth",
                   "PremLife" : "YearlyPremLife",
                   "PremWork" : "YearlyPremWork"}, inplace=True)
# taxa de esforço? taxa de esforço por seguro, ou anual?

# %% [markdown]
# ## Outliers

# %%
# vars com outliers
sns.set_style(style="darkgrid") 
f, axes = plt.subplots(nrows=3, ncols=3, figsize=(20,15))

sns.boxplot(data=df, y='FirstPolYear', ax=axes[0][0]).set(ylabel=None);
sns.boxplot(data=df, y='BirthYear', ax=axes[0][1]).set(ylabel=None);
sns.boxplot(data=df, y='MonthSal', ax=axes[0][2]).set(ylabel=None);
sns.boxplot(data=df, y='CustMonVal', ax=axes[1][0]).set(ylabel=None);
sns.boxplot(data=df, y='ClaimsRate', ax=axes[1][1]).set(ylabel=None);
sns.boxplot(data=df, y='PremMotor', ax=axes[1][2]).set(ylabel=None);
sns.boxplot(data=df, y='PremHousehold', ax=axes[2][0]).set(ylabel=None);
sns.boxplot(data=df, y='PremHealth', ax=axes[2][1]).set(ylabel=None);
sns.boxplot(data=df, y='PremLife', ax=axes[2][2]).set(ylabel=None);

axes[0][0].set(title='FirstPolYear');
axes[0][1].set(title='BirthYear');
axes[0][2].set(title='MonthSal');
axes[1][0].set(title='CustMonVal');
axes[1][1].set(title='ClaimsRate');
axes[1][2].set(title='PremMotor');
axes[2][0].set(title='PremHousehold');
axes[2][1].set(title='PremHealth');
axes[2][2].set(title='PremLife');

plt.show();

# %% [markdown]
# ### Remoção outliers

# %%
df[df.YearlyPremHousehold > 10000].T
# Out:
#                                     8866
# CustID                        8867.00000
# FirstPolYear                  1978.00000
# BirthYear                     1972.00000
# EducDeg               b'2 - High School'
# MonthSal                      2618.00000
# GeoLivArea                       4.00000
# Children                         1.00000
# CustMonVal                     473.54000
# ClaimsRate                       0.98000
# YearlyPremMotor                508.43000
# YearlyPremHousehold          25048.80000
# YearlyPremHealth                36.23000
# YearlyPremLife                   9.89000
# YearlyPremWork                  11.89000
# PremSum                      25615.24000
# Age                             44.00000
# YearsOfCustomer                 38.00000
# MonthlyPremMotor                42.36917
# MonthlyPremHousehold          2087.40000
# MonthlyPremHealth                3.01917
# MonthlyPremLife                  0.82417
# MonthlyPremWork                  0.99083
# MonthlyPremSum                2134.60333
# YearlyMonthSal               31416.00000

# %%
df = df[df.FirstPolYear < 50000]  # 1, 9295
df = df[df.BirthYear > 1900]      # 1, 7196
df = df[df.MonthSal < 20000]      # 2, 5883, 8262
df = df[df.CustMonVal > -10000] # 9, 52, 136, 172, 656, 676, 708, 759, 918, 9649
df = df[df.PremHealth < 10000]    # 1 9150
df = df[df.PremHealth < 5000]    # 1 9150

# df = df[df.PremHealth < 10000] # 1
# df = df[df.PremHousehold < 10000] # 1

# %%
#df = df.drop(labels=['FirstPolYear', 'BirthYear'], axis=1)
plt.figure(figsize=(20, 10))

heatmap = sns.heatmap(df.corr(), annot=True);

# %%
# vars com outliers
sns.set_style(style="darkgrid") 
f, axes = plt.subplots(nrows=3, ncols=3, figsize=(20,15))

sns.distplot(df["Age"], bins=[0, 10, 20, 30, 40, 50, 60, 70], ax=axes[0][0]).set(xlabel=None);
sns.distplot(df["YearsOfCustomer"], bins=[0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50], ax=axes[0][1]).set(xlabel=None);
#sns.distplot(df["FirstPolYear"], bins=[1960, 1970, 1980, 1990, 2000, 2010], ax=axes[0][0]).set(xlabel=None);
#sns.distplot(df["BirthYear"], bins=[1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010], ax=axes[0][1]).set(xlabel=None);
sns.distplot(df["MonthSal"], bins=[0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000], ax=axes[0][2]).set(xlabel=None);
sns.distplot(df["CustMonVal"], ax=axes[1][0]).set(xlabel=None);
sns.distplot(df["ClaimsRate"], ax=axes[1][1]).set(xlabel=None);
sns.distplot(df["PremMotor"], ax=axes[1][2]).set(xlabel=None);
sns.distplot(df["PremHousehold"], ax=axes[2][0]).set(xlabel=None);
sns.distplot(df["PremHealth"], ax=axes[2][1]).set(xlabel=None);
sns.distplot(df["PremLife"], ax=axes[2][2]).set(xlabel=None);


axes[0][0].set(title='Age');
axes[0][1].set(title='YearsOfCustomer');
axes[0][2].set(title='MonthSal');
axes[1][0].set(title='CustMonVal');
axes[1][1].set(title='ClaimsRate');
axes[1][2].set(title='PremMotor');
axes[2][0].set(title='PremHousehold');
axes[2][1].set(title='PremHealth');
axes[2][2].set(title='PremLife');

plt.show();

# %% [markdown]
# ### Exploração

# %% [markdown]
# #### df_test.PremSum > df_test.MonthSal ---> 579

# %%
df[df.MonthlyPremSum > df.MonthSal] # 579
# Out:
# Empty DataFrame
# Columns: [CustID, FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, PremMotor, PremHousehold, PremHealth, PremLife, PremWork, PremSum, Age, YearsOfCustomer, MonthlyPremMotor, MonthlyPremHousehold, MonthlyPremHealth, MonthlyPremLife, MonthlyPremWork, MonthlyPremSum]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# #### df.BirthYear > df.FirstPolYear ---> 1997

# %%
df[df.BirthYear > df.FirstPolYear]
# Out:
#            CustID  FirstPolYear  BirthYear             EducDeg   MonthSal  \
# 1         2.00000    1981.00000 1995.00000  b'2 - High School'  677.00000
# 13       14.00000    1983.00000 2000.00000        b'1 - Basic' 1043.00000
# 18       19.00000    1981.00000 1982.00000        b'1 - Basic' 1414.00000
# 22       23.00000    1976.00000 1986.00000  b'2 - High School' 1495.00000
# 40       41.00000    1994.00000 1995.00000  b'2 - High School' 1177.00000
# ...           ...           ...        ...                 ...        ...
# 10268 10269.00000    1987.00000 1988.00000      b'3 - BSc/MSc' 1414.00000
# 10273 10274.00000    1989.00000 1992.00000  b'2 - High School' 1035.00000
# 10284 10285.00000    1980.00000 1987.00000      b'3 - BSc/MSc' 1504.00000
# 10288 10289.00000    1982.00000 1993.00000  b'2 - High School' 1465.00000
# 10290 10291.00000    1994.00000 1999.00000        b'1 - Basic'  626.00000
#
#        GeoLivArea  Children  CustMonVal  ClaimsRate  PremMotor  ...  PremWork  \
# 1         4.00000   1.00000  -131.13000     1.12000   77.46000  ... 106.13000
# 13        3.00000   1.00000   -75.12000     1.06000   44.34000  ...  94.46000
# 18        3.00000   1.00000   230.38000     0.71000  313.17000  ...  72.57000
# 22        1.00000   1.00000   -89.79000     1.08000  209.04000  ...  54.90000
# 40        4.00000   1.00000   121.36000     0.84000   52.01000  ... 148.03000
# ...           ...       ...         ...         ...        ...  ...       ...
# 10268     3.00000   1.00000    50.46000     0.90000  129.58000  ...  75.46000
# 10273     1.00000   1.00000   293.51000     0.58000  235.71000  ...  58.12000
# 10284     4.00000   1.00000    -1.55000     0.96000  390.63000  ...       nan
# 10288     1.00000   1.00000   795.15000     0.35000   67.79000  ...  86.46000
# 10290     3.00000   1.00000   176.26000     0.85000    6.89000  ... 201.26000
#
#          PremSum      Age  YearsOfCustomer  MonthlyPremMotor  \
# 1      910.96000 21.00000         35.00000           6.45500
# 13     877.28000 16.00000         33.00000           3.69500
# 18     895.72000 34.00000         35.00000          26.09750
# 22     830.16000 30.00000         40.00000          17.42000
# 40     937.52000 21.00000         22.00000           4.33417
# ...          ...      ...              ...               ...
# 10268  723.24000 28.00000         29.00000          10.79833
# 10273  763.48000 24.00000         27.00000          19.64250
# 10284        nan 29.00000         36.00000          32.55250
# 10288 1259.01000 23.00000         34.00000           5.64917
# 10290 1302.80000 17.00000         22.00000           0.57417
#
#        MonthlyPremHousehold  MonthlyPremHealth  MonthlyPremLife  \
# 1                  34.68333            9.72417         16.20667
# 13                 28.57083           10.64083         22.32833
# 18                 31.11667           10.15000          1.23167
# 22                 25.74583           16.04000          5.39917
# 40                 37.97083           11.28917         12.19667
# ...                     ...                ...              ...
# 10268              13.98333           15.37333         13.82667
# 10273              16.30000            8.59417         14.24333
# 10284               2.45417           14.97500         -0.50000
# 10288              68.34583            8.51083         15.20667
# 10290              73.20833            8.59417          9.41833
#
#        MonthlyPremWork  MonthlyPremSum
# 1              8.84417        75.91333
# 13             7.87167        73.10667
# 18             6.04750        74.64333
# 22             4.57500        69.18000
# 40            12.33583        78.12667
# ...                ...             ...
# 10268          6.28833        60.27000
# 10273          4.84333        63.62333
# 10284              nan             nan
# 10288          7.20500       104.91750
# 10290         16.77167       108.56667
#
# [1970 rows x 23 columns]

# %%
# correlacoes com MonthSal
sns.set_style(style="darkgrid") 
f, axes = plt.subplots(nrows=3, ncols=3, figsize=(20,15))

sns.scatterplot(data=df, x="Age", y="MonthSal", ax=axes[0][0]).set(xlabel=None);
sns.scatterplot(data=df, x="YearsOfCustomer", y="MonthSal", ax=axes[0][1]).set(xlabel=None);
sns.scatterplot(data=df, x="EducDeg", y="MonthSal", ax=axes[0][2]).set(xlabel=None);
sns.scatterplot(data=df, x="GeoLivArea", y="MonthSal", ax=axes[1][0]).set(xlabel=None);
sns.scatterplot(data=df, x="Children", y="MonthSal", ax=axes[1][1]).set(xlabel=None);
sns.scatterplot(data=df, x="Age", y="MonthSal", ax=axes[1][2]).set(xlabel=None);
sns.scatterplot(data=df, x="Age", y="MonthSal", ax=axes[2][0]).set(xlabel=None);
sns.scatterplot(data=df, x="Age", y="MonthSal", ax=axes[2][1]).set(xlabel=None);
sns.scatterplot(data=df, x="Age", y="MonthSal", ax=axes[2][2]).set(xlabel=None);

axes[0][0].set(title='Age');
axes[0][1].set(title='YearsOfCustomer');
axes[0][2].set(title='EducDeg');
axes[1][0].set(title='GeoLivArea');
axes[1][1].set(title='Children');
axes[1][2].set(title='___');
axes[2][0].set(title='___');
axes[2][1].set(title='___');
axes[2][2].set(title='___');

plt.show();

# %%
df.MonthSal.describe()
# Out:
# count   10214.00000
# mean     2497.59888
# std       984.81256
# min       333.00000
# 25%      1705.00000
# 50%      2500.00000
# 75%      3290.00000
# max      5021.00000
# Name: MonthSal, dtype: float64

# %%
df['MonthSal'].describe(percentiles=[0.0005,0.005,0.01,0.15,0.25,0.5,0.7,0.9, 0.95])
df[df.MonthSal > 20000]
# Out:
# count   10214.00000
# mean     2497.59888
# std       984.81256
# min       333.00000
# 0.05%     335.00000
# 0.5%      427.06500
# 1%        557.52000
# 15%      1372.00000
# 25%      1705.00000
# 50%      2500.00000
# 70%      3129.00000
# 90%      3822.00000
# 95%      4045.00000
# max      5021.00000
# Name: MonthSal, dtype: float64
# Empty DataFrame
# Columns: [CustID, FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, PremMotor, PremHousehold, PremHealth, PremLife, PremWork, PremSum, Age, YearsOfCustomer]
# Index: []

# %%
df['BirthYear'].describe(percentiles=[0.0005,0.005,0.01,0.15,0.25,0.5,0.7,0.9])
df[df.BirthYear < 1800]
# Out:
# count   10279.00000
# mean     1968.00778
# std        19.70948
# min      1028.00000
# 0.05%    1935.00000
# 0.5%     1936.39000
# 1%       1937.00000
# 15%      1947.00000
# 25%      1953.00000
# 50%      1968.00000
# 70%      1980.00000
# 90%      1992.00000
# max      2001.00000
# Name: BirthYear, dtype: float64
#          CustID  FirstPolYear  BirthYear         EducDeg   MonthSal  \
# 7195 7196.00000    1993.00000 1028.00000  b'3 - BSc/MSc' 2830.00000
#
#       GeoLivArea  Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  \
# 7195     4.00000   0.00000   146.02000     0.77000  428.97000      192.80000
#
#       PremHealth  PremLife  PremWork
# 7195   108.91000   1.89000  23.67000

# %% [markdown]
# ## Null values

# %%
df[df.MonthlyPremHousehold == 0] # 27
# Out:
#          CustID  FirstPolYear  BirthYear             EducDeg   MonthSal  \
# 629   630.00000    1987.00000 1968.00000      b'3 - BSc/MSc' 2483.00000
# 912   913.00000    1998.00000 1980.00000  b'2 - High School' 2093.00000
# 1059 1060.00000    1977.00000 1967.00000      b'3 - BSc/MSc' 3297.00000
# 1289 1290.00000    1980.00000 1944.00000      b'3 - BSc/MSc' 3962.00000
# 1376 1377.00000    1983.00000 1977.00000      b'3 - BSc/MSc' 1460.00000
# 2226 2227.00000    1976.00000 1952.00000  b'2 - High School' 2825.00000
# 2564 2565.00000    1992.00000 1941.00000      b'3 - BSc/MSc' 4843.00000
# 2593 2594.00000    1994.00000 1948.00000  b'2 - High School' 3745.00000
# 2721 2722.00000    1996.00000 1971.00000      b'3 - BSc/MSc' 2596.00000
# 2891 2892.00000    1985.00000 1982.00000      b'3 - BSc/MSc' 1343.00000
# 3129 3130.00000    1982.00000 1968.00000      b'3 - BSc/MSc' 2827.00000
# 3450 3451.00000    1977.00000 1966.00000      b'3 - BSc/MSc' 3094.00000
# 4861 4862.00000    1987.00000 1955.00000      b'3 - BSc/MSc' 2740.00000
# 4908 4909.00000    1974.00000 1982.00000          b'4 - PhD' 1826.00000
# 5049 5050.00000    1984.00000 1971.00000  b'2 - High School' 2923.00000
# 5399 5400.00000    1983.00000 1969.00000  b'2 - High School' 2697.00000
# 5846 5847.00000    1985.00000 1936.00000  b'2 - High School' 3812.00000
# 6400 6401.00000    1982.00000 1962.00000      b'3 - BSc/MSc' 2643.00000
# 6728 6729.00000    1980.00000 1960.00000      b'3 - BSc/MSc' 2701.00000
# 7590 7591.00000    1978.00000 1972.00000      b'3 - BSc/MSc' 2198.00000
# 8144 8145.00000    1985.00000 1974.00000  b'2 - High School' 1507.00000
# 8534 8535.00000    1976.00000 1943.00000      b'3 - BSc/MSc' 3607.00000
# 8658 8659.00000    1990.00000 1971.00000      b'3 - BSc/MSc' 2088.00000
# 8853 8854.00000    1975.00000 1962.00000  b'2 - High School' 3107.00000
# 8917 8918.00000    1978.00000 1995.00000  b'2 - High School'  936.00000
# 9479 9480.00000    1983.00000 1962.00000  b'2 - High School' 3240.00000
# 9688 9689.00000    1990.00000 1972.00000          b'4 - PhD' 1563.00000
#
#       GeoLivArea  Children  CustMonVal  ClaimsRate  YearlyPremMotor  ...  \
# 629      3.00000   1.00000   -37.00000     1.02000        523.32000  ...
# 912      4.00000   1.00000   295.95000     0.46000        296.39000  ...
# 1059     1.00000   1.00000   484.43000     0.12000        511.43000  ...
# 1289     4.00000   0.00000  -123.46000     1.16000        184.70000  ...
# 1376     3.00000   1.00000   184.15000     0.62000        285.83000  ...
# 2226     4.00000   1.00000   253.83000     0.52000        278.83000  ...
# 2564     4.00000   0.00000   -48.45000     1.04000        231.49000  ...
# 2593     4.00000   0.00000   391.64000     0.26000        182.59000  ...
# 2721     4.00000   1.00000   375.41000     0.32000        384.85000  ...
# 2891     1.00000   1.00000   -63.67000     1.07000        433.97000  ...
# 3129     4.00000   1.00000   487.43000     0.12000        496.65000  ...
# 3450     4.00000   0.00000   523.99000     0.08000        541.88000  ...
# 4861     1.00000   1.00000   -23.00000     1.00000        319.17000  ...
# 4908     3.00000   1.00000   401.86000     0.29000        435.86000  ...
# 5049     4.00000   1.00000   527.77000     0.06000        557.77000  ...
# 5399     2.00000   1.00000   -31.55000     1.01000        488.76000  ...
# 5846     1.00000   0.00000   273.50000     0.45000        237.71000  ...
# 6400     3.00000   1.00000   -25.00000     1.00000        545.88000  ...
# 6728     1.00000   0.00000   483.43000     0.13000        490.65000  ...
# 7590     4.00000   1.00000   -51.89000     1.05000        557.66000  ...
# 8144     4.00000   1.00000   505.88000     0.08000        550.88000  ...
# 8534     3.00000   0.00000   -16.22000     0.98000        327.73000  ...
# 8658     4.00000   1.00000   -17.33000     0.99000        503.76000  ...
# 8853     4.00000   1.00000    36.79000     0.87000        149.03000  ...
# 8917     3.00000   1.00000  -110.24000     1.18000         32.56000  ...
# 9479     4.00000   1.00000   -18.00000     0.99000        555.55000  ...
# 9688     4.00000   0.00000   520.88000     0.08000        553.77000  ...
#
#        PremSum      Age  YearsOfCustomer  MonthlyPremMotor  \
# 629  581.11000 48.00000         29.00000          43.61000
# 912  592.00000 36.00000         18.00000          24.69917
# 1059 582.00000 49.00000         39.00000          42.61917
# 1289 620.00000 72.00000         36.00000          15.39167
# 1376       nan 39.00000         33.00000          23.81917
# 2226 582.00000 64.00000         40.00000          23.23583
# 2564 573.00000 75.00000         24.00000          19.29083
# 2593 563.00000 68.00000         22.00000          15.21583
# 2721 588.00000 45.00000         20.00000          32.07083
# 2891 594.00000 34.00000         31.00000          36.16417
# 3129 582.00000 48.00000         34.00000          41.38750
# 3450 597.00000 50.00000         39.00000          45.15667
# 4861 591.00000 61.00000         29.00000          26.59750
# 4908 598.00000 34.00000         42.00000          36.32167
# 5049 590.11000 45.00000         32.00000          46.48083
# 5399 566.00000 47.00000         33.00000          40.73000
# 5846 539.99000 80.00000         31.00000          19.80917
# 6400 598.11000 54.00000         34.00000          45.49000
# 6728       nan 56.00000         36.00000          40.88750
# 7590 589.00000 44.00000         38.00000          46.47167
# 8144 575.11000 42.00000         31.00000          45.90667
# 8534 559.00000 73.00000         40.00000          27.31083
# 8658 601.00000 45.00000         26.00000          41.98000
# 8853 476.65000 54.00000         41.00000          12.41917
# 8917 463.64000 21.00000         38.00000           2.71333
# 9479 596.00000 54.00000         33.00000          46.29583
# 9688 593.00000 44.00000         26.00000          46.14750
#
#       MonthlyPremHousehold  MonthlyPremHealth  MonthlyPremLife  \
# 629                0.00000            5.81583         -0.41667
# 912                0.00000           22.58750          1.47250
# 1059               0.00000            4.89917          0.57417
# 1289               0.00000           28.07000          3.76917
# 1376               0.00000           15.22500          6.39000
# 2226               0.00000           10.13167         10.39083
# 2564               0.00000           25.52333          0.98167
# 2593               0.00000           12.17833         19.54083
# 2721               0.00000           13.58583          2.04667
# 2891               0.00000           12.11333          1.72250
# 3129               0.00000            5.30667          1.31500
# 3450               0.00000            3.85250          0.07417
# 4861               0.00000           20.20750          1.13917
# 4908               0.00000           12.44667          0.90750
# 5049               0.00000            2.44500         -0.33333
# 5399               0.00000            6.62167         -0.00917
# 5846               0.00000           18.55917          5.06583
# 6400               0.00000            3.93583          0.16667
# 6728               0.00000            6.13083          1.48167
# 7590               0.00000            2.62083          0.74083
# 8144               0.00000            2.85250         -0.41667
# 8534               0.00000           13.65083          2.44500
# 8658               0.00000            6.29750         -0.58333
# 8853               0.00000           17.57750          7.27000
# 8917               0.00000           22.32833          9.81667
# 9479               0.00000            2.03750          0.58333
# 9688               0.00000            2.77833          0.57417
#
#       MonthlyPremWork  MonthlyPremSum  YearlyMonthSal
# 629          -0.58333        48.42583     29796.00000
# 912           0.57417        49.33333     25116.00000
# 1059          0.40750        48.50000     39564.00000
# 1289          4.43583        51.66667     47544.00000
# 1376              nan             nan     17520.00000
# 2226          4.74167        48.50000     33900.00000
# 2564          1.95417        47.75000     58116.00000
# 2593         -0.01833        46.91667     44940.00000
# 2721          1.29667        49.00000     31152.00000
# 2891         -0.50000        49.50000     16116.00000
# 3129          0.49083        48.50000     33924.00000
# 3450          0.66667        49.75000     37128.00000
# 4861          1.30583        49.25000     32880.00000
# 4908          0.15750        49.83333     21912.00000
# 5049          0.58333        49.17583     35076.00000
# 5399         -0.17583        47.16667     32364.00000
# 5846          1.56500        44.99917     45744.00000
# 6400          0.25000        49.84250     31716.00000
# 6728              nan             nan     32412.00000
# 7590         -0.75000        49.08333     26376.00000
# 8144         -0.41667        47.92583     18084.00000
# 8534          3.17667        46.58333     43284.00000
# 8658          2.38917        50.08333     25056.00000
# 8853          2.45417        39.72083     37284.00000
# 8917          3.77833        38.63667     11232.00000
# 9479          0.75000        49.66667     38880.00000
# 9688         -0.08333        49.41667     18756.00000
#
# [27 rows x 24 columns]

# %%
df[df.MonthlyPremHealth == 0] # 0
# Out:
# Empty DataFrame
# Columns: [CustID, FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, YearlyPremMotor, YearlyPremHousehold, YearlyPremHealth, YearlyPremLife, YearlyPremWork, PremSum, Age, YearsOfCustomer, MonthlyPremMotor, MonthlyPremHousehold, MonthlyPremHealth, MonthlyPremLife, MonthlyPremWork, MonthlyPremSum, YearlyMonthSal]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[df.MonthlyPremLife == 0] # 0
# Out:
# Empty DataFrame
# Columns: [CustID, FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, YearlyPremMotor, YearlyPremHousehold, YearlyPremHealth, YearlyPremLife, YearlyPremWork, PremSum, Age, YearsOfCustomer, MonthlyPremMotor, MonthlyPremHousehold, MonthlyPremHealth, MonthlyPremLife, MonthlyPremWork, MonthlyPremSum, YearlyMonthSal]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[df.MonthlyPremWork == 0] # 0
# Out:
# Empty DataFrame
# Columns: [CustID, FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, YearlyPremMotor, YearlyPremHousehold, YearlyPremHealth, YearlyPremLife, YearlyPremWork, PremSum, Age, YearsOfCustomer, MonthlyPremMotor, MonthlyPremHousehold, MonthlyPremHealth, MonthlyPremLife, MonthlyPremWork, MonthlyPremSum, YearlyMonthSal]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[df.MonthlyPremMotor == 0]
# Out:
# Empty DataFrame
# Columns: [CustID, FirstPolYear, BirthYear, EducDeg, MonthSal, GeoLivArea, Children, CustMonVal, ClaimsRate, YearlyPremMotor, YearlyPremHousehold, YearlyPremHealth, YearlyPremLife, YearlyPremWork, PremSum, Age, YearsOfCustomer, MonthlyPremMotor, MonthlyPremHousehold, MonthlyPremHealth, MonthlyPremLife, MonthlyPremWork, MonthlyPremSum, YearlyMonthSal]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# CustID             0
# FirstPolYear       0
# BirthYear          0
# EducDeg            2
# MonthSal          34
# GeoLivArea         0
# Children          13
# CustMonVal         0
# ClaimsRate         0
# PremMotor         34
# PremHousehold      0
# PremHealth        43
# PremLife         104
# PremWork          85
# dtype: int64

# %%
df.head(5)
# Out:
#    CustID  FirstPolYear  BirthYear             EducDeg   MonthSal  GeoLivArea  \
# 0 1.00000    1985.00000 1982.00000  b'2 - High School' 2177.00000     1.00000
# 1 2.00000    1981.00000 1995.00000  b'2 - High School'  677.00000     4.00000
# 2 3.00000    1991.00000 1970.00000        b'1 - Basic' 2277.00000     3.00000
# 3 4.00000    1990.00000 1981.00000      b'3 - BSc/MSc' 1099.00000     4.00000
# 4 5.00000    1986.00000 1973.00000      b'3 - BSc/MSc' 1763.00000     4.00000
#
#    Children  CustMonVal  ClaimsRate  PremMotor  PremHousehold  PremHealth  \
# 0   1.00000   380.97000     0.39000  375.85000       79.45000   146.36000
# 1   1.00000  -131.13000     1.12000   77.46000      416.20000   116.69000
# 2   0.00000   504.67000     0.28000  206.15000      224.50000   124.58000
# 3   1.00000   -16.99000     0.99000  182.48000       43.35000   311.17000
# 4   1.00000    35.23000     0.90000  338.62000       47.80000   182.59000
#
#    PremLife  PremWork   PremSum      Age  YearsOfCustomer
# 0  47.01000  16.89000 665.56000 34.00000         31.00000
# 1 194.48000 106.13000 910.96000 21.00000         35.00000
# 2  86.35000  99.02000 740.60000 46.00000         25.00000
# 3  35.34000  28.34000 600.68000 35.00000         26.00000
# 4  18.78000  41.45000 629.24000 43.00000         30.00000

# %% [markdown]
# ### categorical

# %% [markdown]
# ### intevalar

# %%
- categorical vars -> intervalar vars
- outliers table
- normalizar
